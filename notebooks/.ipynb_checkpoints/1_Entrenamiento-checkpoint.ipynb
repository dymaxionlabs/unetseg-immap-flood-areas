# %% [markdown]
# # Zonas inundables
#
# ## 1_ Entrenamiento del modelo
#
#    En este nootbook se realiza el entrenamiento del modelo de de ML. Es una red neuronal convolucional CNN con una arquitectura U-Net. Dicha red requiere un dataset compuesto por imágenes y máscaras para el entrenamiento. Estas últimas son imágenes binarias que delimitan el objeto de interés, donde los píxeles tienen valor 1 donde está el objeto y 0 donde no.
#
# ### Generacion del data set de entrenamiento
#
#    En esta etapa generamos el dataset de entrenamiento mediante el uso **Satproc**. Esta herramienta permite generar el dataset con todas las caracteristicas necesarias para el modelo: tamaño , cantidad de imagenes, rango de valores, etc.

# %%
# !ls ../images/
# Out:
# dataset_training_500m_epsg4326.tif

# %%
BUCKET_TRAIN = "gs://dym-indunor-temp/immap/v3_1/srtm/training/dataset_training_500m_epsg4326.tif" #CHECK

#creamos la carpeta a donde descargaremos las imagenes
BASE_PATH = "../"
PATH_S1_IMAGES_TRAIN = f"{BASE_PATH}/images/"

ANNOTATIONS_FILE_NAME = f"inundacion_nina_2011_trainingAOI.geojson"
AOI_FILE_NAME = f"inundacion_nina_2011_trainingAOI.geojson"

SIZE =160
STEP_SIZE = 160
MODEL_VERSION = "v0"
MODEL = f'UNet_TEST_160x160_spe100_7N_flood_aeras_colombia_{MODEL_VERSION}.h5'

BUCKET_MODELO = ""

# %% [markdown]
# **Descarga de imágenes**

# %%
#!mkdir -p $PATH_S1_IMAGES_TRAIN  

#!gsutil -m cp -r $BUCKET_TRAIN   $PATH_S1_IMAGES_TRAIN

# %% [markdown]
# Podemos verificar que los archivos fueron correctamente descargados

# %%
#!ls $PATH_S1_IMAGES_TRAIN

# %% [markdown]
# **Satproc**
#
# Con la herramienta **satproc_extract_chips** se generan, a partir de las imágenes descargadas del bucket, imágenes (chips) generalmente mas pequeñas y máscaras (utilizando las anotaciones de verdad de campo).

# %%
path_to_files   = f'{PATH_S1_IMAGES_TRAIN}*.tif' #carpeta a las imagenes
dataset_folder  = f'{BASE_PATH}/dataset/data_train/{str(SIZE)}_{str(STEP_SIZE)}/' #carpeta de destino del dataset
vector_file     = f'{BASE_PATH}data/shp/gt/'+ ANNOTATIONS_FILE_NAME # archivo vectorial de verdad de campo
vector_file_aoi = vector_file#f'{BASE_PATH}data/shp/' + AOI_FILE_NAME

# %% [markdown]
# **OBS** : tanto las imágenes como el archivo vectorial deben tener la misma georeferencia, por ejemplo 4326

# %% [markdown]
# Ejecutamos satproc

# %%
#!pip install pysatproc

# %%
# !satproc_extract_chips \
                $path_to_files \
                -o  $dataset_folder \
                --size $SIZE \
                --step-size $STEP_SIZE \
                --aoi $vector_file_aoi \
                --labels $vector_file \
                --label-property 'class' \
                --classes 'F' \
                --rescale \
                --rescale-mode percentiles  --lower-cut 0 --upper-cut 100
# Out:
# Rasters:   0%|                                            | 0/1 [00:00<?, ?it/s]
# dataset_training_500m_epsg4326.tif windows:   0%|        | 0/85 [00:00<?, ?it/s]
# dataset_training_500m_epsg4326.tif windows:   1%| | 1/85 [00:00<00:56,  1.50it/s
# dataset_training_500m_epsg4326.tif windows:   2%| | 2/85 [00:01<00:55,  1.51it/s
# dataset_training_500m_epsg4326.tif windows:   4%| | 3/85 [00:02<00:59,  1.38it/s
# dataset_training_500m_epsg4326.tif windows:   5%| | 4/85 [00:02<00:59,  1.35it/s
# dataset_training_500m_epsg4326.tif windows:   6%| | 5/85 [00:03<00:59,  1.35it/s
# dataset_training_500m_epsg4326.tif windows:   7%| | 6/85 [00:04<00:58,  1.34it/s
# dataset_training_500m_epsg4326.tif windows:   8%| | 7/85 [00:05<00:59,  1.32it/s
# dataset_training_500m_epsg4326.tif windows:   9%| | 8/85 [00:05<00:58,  1.32it/s
# dataset_training_500m_epsg4326.tif windows:  11%|1| 9/85 [00:06<00:57,  1.32it/s
# dataset_training_500m_epsg4326.tif windows:  12%|1| 10/85 [00:07<00:56,  1.32it/
# dataset_training_500m_epsg4326.tif windows:  13%|1| 11/85 [00:08<00:56,  1.30it/
# dataset_training_500m_epsg4326.tif windows:  14%|1| 12/85 [00:08<00:55,  1.31it/
# dataset_training_500m_epsg4326.tif windows:  15%|1| 13/85 [00:09<00:54,  1.32it/
# dataset_training_500m_epsg4326.tif windows:  16%|1| 14/85 [00:10<00:54,  1.31it/
# dataset_training_500m_epsg4326.tif windows:  18%|1| 15/85 [00:11<00:54,  1.28it/
# dataset_training_500m_epsg4326.tif windows:  19%|1| 16/85 [00:12<00:53,  1.28it/
# dataset_training_500m_epsg4326.tif windows:  20%|2| 17/85 [00:12<00:53,  1.28it/
# dataset_training_500m_epsg4326.tif windows:  21%|2| 18/85 [00:13<00:52,  1.28it/
# dataset_training_500m_epsg4326.tif windows:  22%|2| 19/85 [00:14<00:52,  1.26it/
# dataset_training_500m_epsg4326.tif windows:  24%|2| 20/85 [00:15<00:52,  1.25it/
# dataset_training_500m_epsg4326.tif windows:  25%|2| 21/85 [00:16<00:51,  1.23it/
# dataset_training_500m_epsg4326.tif windows:  26%|2| 22/85 [00:16<00:51,  1.23it/
# dataset_training_500m_epsg4326.tif windows:  27%|2| 23/85 [00:17<00:51,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  28%|2| 24/85 [00:18<00:50,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  29%|2| 25/85 [00:19<00:49,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  31%|3| 26/85 [00:20<00:48,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  32%|3| 27/85 [00:21<00:48,  1.19it/
# dataset_training_500m_epsg4326.tif windows:  33%|3| 28/85 [00:22<00:47,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  34%|3| 29/85 [00:22<00:46,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  35%|3| 30/85 [00:23<00:45,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  36%|3| 31/85 [00:24<00:45,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  38%|3| 32/85 [00:25<00:43,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  39%|3| 33/85 [00:26<00:42,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  40%|4| 34/85 [00:26<00:42,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  41%|4| 35/85 [00:27<00:41,  1.20it/
# dataset_training_500m_epsg4326.tif windows:  42%|4| 36/85 [00:28<00:40,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  44%|4| 37/85 [00:29<00:39,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  45%|4| 38/85 [00:30<00:38,  1.21it/
# dataset_training_500m_epsg4326.tif windows:  46%|4| 39/85 [00:31<00:37,  1.23it/
# dataset_training_500m_epsg4326.tif windows:  47%|4| 40/85 [00:31<00:36,  1.24it/
# dataset_training_500m_epsg4326.tif windows:  48%|4| 41/85 [00:32<00:35,  1.25it/
# dataset_training_500m_epsg4326.tif windows:  49%|4| 42/85 [00:33<00:34,  1.24it/
# dataset_training_500m_epsg4326.tif windows:  51%|5| 43/85 [00:34<00:33,  1.25it/
# dataset_training_500m_epsg4326.tif windows:  52%|5| 44/85 [00:34<00:31,  1.28it/
# dataset_training_500m_epsg4326.tif windows:  53%|5| 45/85 [00:35<00:30,  1.31it/
# dataset_training_500m_epsg4326.tif windows:  54%|5| 46/85 [00:36<00:30,  1.30it/
# dataset_training_500m_epsg4326.tif windows:  55%|5| 47/85 [00:37<00:28,  1.32it/
# dataset_training_500m_epsg4326.tif windows:  56%|5| 48/85 [00:37<00:27,  1.33it/
# dataset_training_500m_epsg4326.tif windows:  58%|5| 49/85 [00:38<00:26,  1.34it/
# dataset_training_500m_epsg4326.tif windows:  59%|5| 50/85 [00:39<00:26,  1.34it/
# dataset_training_500m_epsg4326.tif windows:  60%|6| 51/85 [00:40<00:25,  1.36it/
# dataset_training_500m_epsg4326.tif windows:  61%|6| 52/85 [00:40<00:24,  1.37it/
# dataset_training_500m_epsg4326.tif windows:  62%|6| 53/85 [00:41<00:23,  1.38it/
# dataset_training_500m_epsg4326.tif windows:  64%|6| 54/85 [00:42<00:22,  1.36it/
# dataset_training_500m_epsg4326.tif windows:  65%|6| 55/85 [00:43<00:21,  1.37it/
# dataset_training_500m_epsg4326.tif windows:  66%|6| 56/85 [00:43<00:20,  1.39it/
# dataset_training_500m_epsg4326.tif windows:  67%|6| 57/85 [00:44<00:19,  1.41it/
# dataset_training_500m_epsg4326.tif windows:  68%|6| 58/85 [00:45<00:19,  1.39it/
# dataset_training_500m_epsg4326.tif windows:  69%|6| 59/85 [00:45<00:18,  1.41it/
# dataset_training_500m_epsg4326.tif windows:  71%|7| 60/85 [00:46<00:17,  1.42it/
# dataset_training_500m_epsg4326.tif windows:  72%|7| 61/85 [00:47<00:16,  1.42it/
# dataset_training_500m_epsg4326.tif windows:  73%|7| 62/85 [00:47<00:16,  1.42it/
# dataset_training_500m_epsg4326.tif windows:  74%|7| 63/85 [00:48<00:15,  1.44it/
# dataset_training_500m_epsg4326.tif windows:  75%|7| 64/85 [00:49<00:14,  1.46it/
# dataset_training_500m_epsg4326.tif windows:  76%|7| 65/85 [00:49<00:13,  1.48it/
# dataset_training_500m_epsg4326.tif windows:  78%|7| 66/85 [00:50<00:12,  1.49it/
# dataset_training_500m_epsg4326.tif windows:  79%|7| 67/85 [00:51<00:11,  1.52it/
# dataset_training_500m_epsg4326.tif windows:  80%|8| 68/85 [00:51<00:10,  1.55it/
# dataset_training_500m_epsg4326.tif windows:  81%|8| 69/85 [00:52<00:10,  1.57it/
# dataset_training_500m_epsg4326.tif windows:  82%|8| 70/85 [00:53<00:09,  1.55it/
# dataset_training_500m_epsg4326.tif windows:  84%|8| 71/85 [00:53<00:09,  1.50it/
# dataset_training_500m_epsg4326.tif windows:  85%|8| 72/85 [00:54<00:08,  1.47it/
# dataset_training_500m_epsg4326.tif windows:  86%|8| 73/85 [00:55<00:08,  1.41it/
# dataset_training_500m_epsg4326.tif windows:  87%|8| 74/85 [00:56<00:07,  1.38it/
# dataset_training_500m_epsg4326.tif windows:  88%|8| 75/85 [00:56<00:07,  1.33it/
# dataset_training_500m_epsg4326.tif windows:  89%|8| 76/85 [00:57<00:06,  1.30it/
# dataset_training_500m_epsg4326.tif windows:  91%|9| 77/85 [00:58<00:06,  1.27it/
# dataset_training_500m_epsg4326.tif windows:  92%|9| 78/85 [00:59<00:05,  1.27it/
# dataset_training_500m_epsg4326.tif windows:  93%|9| 79/85 [01:00<00:04,  1.31it/
# dataset_training_500m_epsg4326.tif windows:  94%|9| 80/85 [01:00<00:03,  1.34it/
# dataset_training_500m_epsg4326.tif windows:  95%|9| 81/85 [01:01<00:02,  1.35it/
# dataset_training_500m_epsg4326.tif windows:  96%|9| 82/85 [01:02<00:02,  1.43it/
# dataset_training_500m_epsg4326.tif windows:  98%|9| 83/85 [01:02<00:01,  1.49it/
# dataset_training_500m_epsg4326.tif windows:  99%|9| 84/85 [01:03<00:00,  1.54it/
# dataset_training_500m_epsg4326.tif windows: 100%|#| 85/85 [01:03<00:00,  1.33it/
# Rasters: 100%|####################################| 1/1 [01:04<00:00, 64.14s/it]

# %% [markdown]
# ###### Los argumentos:
#
# * **path_to_files** es la ruta a las imágenes
#
# * **o** es la ruta de destino
#
# Recomendamos que dicha ruta sea descriptiva, por ejemplo “data_train/120_40/ ” describe : Data_train → datos usados para entrenar; 120_40 → <tamaño de la imagen >_ <tamaño del step-size>
#
# * **size** tamaño de las imágenes resultantes o chips (las imágenes son cuadradas)
# * **step-size** paso del proceso. Debe ser menor o igual a *size*. Si *step-size* es igual que el *size* entonces no hay overlap en las imágenes resultantes.
#
# En ocasiones es útil para el entrenamiento generar los chips con un overlap de este modo tenemos más datos para entrenar.
#
#
# * **label-property** nombre del campo donde se define cada categoría (solo se usa para el entrenamiento)
#
# * **classes** nombres de las clases (como aparecen en el geojson), separados por espacios
#
# * **aoi** ruta al archivo vectorial donde están definidas las anotaciones. Al definir una region de interés solo se procesan las imágenes que interceptan esas anotaciones.
#
# * **rescale** lleva los valores de las bandas a 0-255
#
# Este comando va a generar dos carpetas en la ruta de destino : “images” y “extent”. Los archivos de la primera van a ser de tipo Tiff de 3 bandas (rgb) y los de la segunda van a ser, también, de tipo Tiff pero de N bandas donde N representa el número de clases, en este caso sólo una. Y donde cada una de las bandas es una máscara binaria

# %% [markdown]
# ## Entrenamiento
#
# Generamos el entrenamiento del modelo utilizando los datasets creados en el paso previo. El modelo es una red neuronal CNN basado en la arquitectura U-Net. Este considera las imágenes y las máscaras binarias como inputs y genera una imagen con la probabilidad de encontrar al objeto de interés.

# %%
from unetseg.train import TrainConfig, train
from unetseg.evaluate import plot_data_generator
import os

# %% [markdown]
# En esta etapa debemos definir la configuración del modelo de ML.

# %% [markdown]
# *Obs*: Es util usar un nombre para el archivo de pesos que de información sobre los parametros de entrenamiento. por ejemplo: < modelo >_< proyecto >_< dim_de_las_imagenes >_< size >_< step_size >_< step_per_epoch >.h5 o similares

# %%
config = TrainConfig(width      = 160,  #  tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320,etc; y no menor a 80)
                     height     = 160,
                     n_channels = 6,  #  número de canales de la imagen, rgb -> 3
                     n_classes  = 1, # número de clases a clasificar
                     apply_image_augmentation = True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes (rotación,)
                     seed       = 42,
                     epochs     = 20, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size = 16, #cantidad de datos que se procesan por vez, puede ser limitado por la memoria de gpu disponible (debe ser multiplo de 16)
                     steps_per_epoch          = 100, #  típicamente debe ser igual al numero de imágenes / el batch_size, si es mayor incrementara el número de imágenes generadas con image augmentation
                     early_stopping_patience  = 5, # a medida que entrena se guardan los resultados del entrenamiento despues de cada epoch, si el error no varió luego de ¿¿10 ?? iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split   = 0.2, # se divide la muestra en training (80% de los datos) y validation (20% de los datos) para calcular el error durante el proceso de entrenamiento
                     test_split         = 0.1, # Cantidad de imágenes del dataset
                     images_path        = dataset_folder,#ruta a las imágenes generadas con Satproc
                     model_path         = os.path.join(BASE_PATH,'data/weights/', MODEL),#  ruta del modelo entrenado
                     model_architecture = 'unet',
                     evaluate           = True  ,
                     class_weights      = [1])

# %% [markdown]
# Podemos visualizar alguna de las imágenes y máscaras del dataset de entrenamiento. A la izquierda se muestra la imágen y a la derecha la máscara

# %%
plot_data_generator(num_samples=3, fig_size=(10, 10), train_config=config,img_ch = 3)

# %% [markdown]
# Corremos el entrenamiento.

# %%
res_config = train(config)
# Out:
# 2022-06-28 15:15:26.455908: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-28 15:15:26.476273: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2022-06-28 15:15:26.555800: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-28 15:15:26.556464: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2022-06-28 15:15:26.556552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2022-06-28 15:15:26.640860: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2022-06-28 15:15:26.640961: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2022-06-28 15:15:26.696706: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2022
UNet_TEST_160x160_spe100_7N_flood_aeras_colombia_v0.h5
# Epoch 4/20
# 100/100 [==============================] - 38s 379ms/step - loss: 0.1556 - mean_io_u: 0.4541 - val_loss: 0.1790 - val_mean_io_u: 0.4472
#
# Epoch 00004: val_loss improved from 0.18720 to 0.17895, saving model to ../data/weights/UNet_TEST_160x160_spe100_7N_flood_aeras_colombia_v0.h5
# Epoch 5/20
# 100/100 [==============================] - 38s 378ms/step - loss: 0.1458 - mean_io_u: 0.4548 - val_loss: 0.2125 - val_mean_io_u: 0.4498
#
# Epoch 00005: val_loss did not improve from 0.17895
# Epoch 6/20
# 100/100 [==============================] - 38s 379ms/step - loss: 0.1368 - mean_io_u: 0.4557 - val_loss: 0.1903 - val_mean_io_u: 0.4464
#
# Epoch 00006: val_loss did not improve from 0.17895
# Epoch 7/20
# 100/100 [==============================] - 38s 380ms/step - loss: 0.1294 - mean_io_u: 0.4590 - val_loss: 0.1932 - val_mean_io_u: 0.4492
#
# Epoch 00007: val_loss did not improve from 0.17895
# Epoch 8/20
# 100/100 [==============================] - 38s 378ms/step - loss: 0.1223 - mean_io_u: 0.4579 - val_loss: 0.1711 - val_mean_io_u: 0.4540
#
# Epoch 00008: val_loss improved from 0.17895 to 0.17113, saving model to ../data/weights/UNet_TEST_160x160_spe100_7N_flood_aeras_colombia_v0.h5
# Epoch 9/20
# 100/100 [==============================] - 37s 376ms/step - loss: 0.1298 - mean_io_u: 0.4553 - val_loss: 0.1787 - val_mean_io_u: 0.4523
#
# Epoch 00009: val_loss did not improve from 0.17113
# Epoch 10/20
# 100/100 [==============================] - 38s 380ms/step - loss: 0.1234 - mean_io_u: 0.4541 - val_loss: 0.1721 - val_mean_io_u: 0.4515
#
# Epoch 00010: val_loss did not improve from 0.17113
# Epoch 11/20
# 100/100 [==============================] - 38s 378ms/step - loss: 0.1182 - mean_io_u: 0.4556 - val_loss: 0.2403 - val_mean_io_u: 0.4466
#
# Epoch 00011: val_loss did not improve from 0.17113
# Epoch 12/20
# 100/100 [==============================] - 39s 387ms/step - loss: 0.1135 - mean_io_u: 0.4575 - val_loss: 0.1926 - val_mean_io_u: 0.4454
#
# Epoch 00012: val_loss did not improve from 0.17113
# Epoch 13/20
# 100/100 [==============================] - 39s 390ms/step - loss: 0.1156 - mean_io_u: 0.4524 - val_loss: 0.1863 - val_mean_io_u: 0.4530
#
# Epoch 00013: val_loss did not improve from 0.17113
# Epoch 00013: early stopping
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0890 - mean_io_u: 0.4890
# *** Final  metrics ***
# Loss: 0.08895374089479446
# Mean IoU: 0.4890210032463074

# %% [markdown]
# Graficamos las métricas generadas.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))

plt.subplot(121)
plt.plot(res_config.history['loss'])
plt.plot(res_config.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(122)
plt.plot(res_config.history['mean_io_u'])
plt.plot(res_config.history['val_mean_io_u'])
plt.title('mean_iou')
plt.ylabel('val_mean_iou')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')


plt.show()

# %%
if SAVE: 
    # !gsutil cp -r config.model_path $BUCKET_MODELO
